# %% [markdown]
# !pip install -U langchain langchain-huggingface faiss-cpu sentence-transformers

# %%
# !pip install -U langchain-community

# %%
import pandas as pd

# Load Questions, Answers, and Tags CSV files
questions_df = pd.read_csv('/kaggle/input/pythonquestions/Questions.csv', encoding='ISO-8859-1')
answers_df = pd.read_csv('/kaggle/input/pythonquestions/Answers.csv', encoding='ISO-8859-1')
tags_df = pd.read_csv('/kaggle/input/pythonquestions/Tags.csv', encoding='ISO-8859-1')

# Fill missing values in the Tag column with an empty string and group tags by question Id
tags_df['Tag'] = tags_df['Tag'].fillna('')
tags_df = tags_df.groupby('Id')['Tag'].apply(lambda x: ' '.join(x)).reset_index()

# Merge questions with answers on Id and ParentId
merged_df = pd.merge(
    questions_df[['Id', 'Title', 'Body']],  # Select relevant columns from questions
    answers_df[['ParentId', 'Body']],       # Select relevant columns from answers
    left_on='Id',
    right_on='ParentId',
    suffixes=('_question', '_answer')
)

# Merge with tags on Id
merged_df = pd.merge(merged_df, tags_df, left_on='Id', right_on='Id', how='left')

# Fill missing tags with an empty string in the merged dataframe
merged_df['Tag'] = merged_df['Tag'].fillna('')

# Combine Title, Body of question, Body of answer, and Tags into a single text for indexing
texts = (
    merged_df['Title'] + " " + 
    merged_df['Body_question'] + " " + 
    merged_df['Body_answer'] + " Tags: " + merged_df['Tag']
).tolist()

print("Merged dataset with tags and prepared texts for indexing.")
# Out:
# Merged dataset with tags and prepared texts for indexing.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from transformers import AutoTokenizer, AutoModel

# Initialize the Hugging Face tokenizer and model, loading the model directly to GPU
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2").to("cuda")

# Initialize the embeddings using the Hugging Face model on GPU
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Set batch size for processing
batch_size = 500
batches = [texts[i:i + batch_size] for i in range(0, len(texts), batch_size)]

# Initialize an empty FAISS vector store
vector_store = None

# Process each batch
for idx, batch in enumerate(batches):
    # Embed the current batch using embed_documents
    batch_embeddings = embeddings.embed_documents(batch)
    
    # Create the FAISS store on the first batch, then add to it for subsequent batches
    if vector_store is None:
        vector_store = FAISS.from_texts(batch, embeddings)
    else:
        vector_store.add_texts(batch)
    
    print(f"Processed batch {idx+1}/{len(batches)} of size {len(batch)}")

print("Vector store created successfully with FAISS!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processed batch 1/1975 of size 500
# Processed batch 2/1975 of size 500
# Processed batch 3/1975 of size 500
# Processed batch 4/1975 of size 500
# Processed batch 5/1975 of size 500
# Processed batch 6/1975 of size 500
# Processed batch 7/1975 of size 500
# Processed batch 8/1975 of size 500
# Processed batch 9/1975 of size 500
# Processed batch 10/1975 of size 500
# Processed batch 11/1975 of size 500
# Processed batch 12/1975 of size 500
# Processed batch 13/1975 of size 500
# Processed batch 14/1975 of size 500
# Processed batch 15/1975 of size 500
# Processed batch 16/1975 of size 500
# Processed batch 17/1975 of size 500
# Processed batch 18/1975 of size 500
# Processed batch 19/1975 of size 500
# Processed batch 20/1975 of size 500
# Processed batch 21/1975 of size 500
# Processed batch 22/1975 of size 500
# Processed batch 23/1975 of size 500
# Processed batch 24/1975 of size 500
# Processed batch 25/1975 of size 500
# Processed batch 26/1975 of size 500
# Processed batch 27/1975 of size 500
# Processed batch 28/1975 of size 500
# Processed batch 29/1975 of size 500
# Processed batch 30/1975 of size 500
# Processed batch 31/1975 of size 500
# Processed batch 32/1975 of size 500
# Processed batch 33/1975 of size 500
# Processed batch 34/1975 of size 500
# Processed batch 35/1975 of size 500
# Processed batch 36/1975 of size 500
# Processed batch 37/1975 of size 500
# Processed batch 38/1975 of size 500
# Processed batch 39/1975 of size 500
# Processed batch 40/1975 of size 500
# Processed batch 41/1975 of size 500
# Processed batch 42/1975 of size 500
# Processed batch 43/1975 of size 500
# Processed batch 44/1975 of size 500
# Processed batch 45/1975 of size 500
# Processed batch 46/1975 of size 500
# Processed batch 47/1975 of size 500
# Processed batch 48/1975 of size 500
# Processed batch 49/1975 of size 500
# Processed batch 50/1975 of size 500
# Processed batch 51/1975 of size 500
# Processed batch 52/1975 of size 500
# Processed batch 53/1975 of size 500
# Processed batch 54/1975 of size 500
# Processed batch 55/1975 of size 500
# Processed batch 56/1975 of size 500
# Processed batch 57/1975 of size 500
# Processed batch 58/1975 of size 500
# Processed batch 59/1975 of size 500
# Processed batch 60/1975 of size 500
# Processed batch 61/1975 of size 500
# Processed batch 62/1975 of size 500
# Processed batch 63/1975 of size 500
# Processed batch 64/1975 of size 500
# Processed batch 65/1975 of size 500
# Processed batch 66/1975 of size 500
# Processed batch 67/1975 of size 500
# Processed batch 68/1975 of size 500
# Processed batch 69/1975 of size 500
# Processed batch 70/1975 of size 500
# Processed batch 71/1975 of size 500
# Processed batch 72/1975 of size 500
# Processed batch 73/1975 of size 500
# Processed batch 74/1975 of size 500
# Processed batch 75/1975 of size 500
# Processed batch 76/1975 of size 500
# Processed batch 77/1975 of size 500
# Processed batch 78/1975 of size 500
# Processed batch 79/1975 of size 500
# Processed batch 80/1975 of size 500
# Processed batch 81/1975 of size 500
# Processed batch 82/1975 of size 500
# Processed batch 83/1975 of size 500
# Processed batch 84/1975 of size 500
# Processed batch 85/1975 of size 500
# Processed batch 86/1975 of size 500
# Processed batch 87/1975 of size 500
# Processed batch 88/1975 of size 500
# Processed batch 89/1975 of size 500
# Processed batch 90/1975 of size 500
# Processed batch 91/1975 of size 500
# Processed batch 92/1975 of size 500
# Processed batch 93/1975 of size 500
# Processed batch 94/1975 of size 500
# Processed batch 95/1975 of size 500
# Processed batch 96/1975 of size 500
# Processed batch 97/1975 of size 500
# Processed batch 98/1975 of size 500
# Processed batch 99/1975 of size 500
# Processed batch 100/1975 of size 500
# Processed batch 101/1975 of size 500
# Processed batch 102/1975 of size 500
# Processed batch 103/1975 of size 500
# Processed batch 104/1975 of size 500
# Processed batch 105/1975 of size 500
# Processed batch 106/1975 of size 500
# Processed batch 107/1975 of size 500
# Processed batch 108/1975 of size 500
# Processed batch 109/1975 of size 500
# Processed batch 110/1975 of size 500
# Processed batch 111/1975 of size 500
# Processed batch 112/1975 of size 500
# Processed batch 113/1975 of size 500
# Processed batch 114/1975 of size 500
# Processed batch 115/1975 of size 500
# Processed batch 116/1975 of size 500
# Processed batch 117/1975 of size 500
# Processed batch 118/1975 of size 500
# Processed batch 119/1975 of size 500
# Processed batch 120/1975 of size 500
# Processed batch 121/1975 of size 500
# Processed batch 122/1975 of size 500
# Processed batch 123/1975 of size 500
# Processed batch 124/1975 of size 500
# Processed batch 125/1975 of size 500
# Processed batch 126/1975 of size 500
# Processed batch 127/1975 of size 500
# Processed batch 128/1975 of size 500
# Processed batch 129/1975 of size 500
# Processed batch 130/1975 of size 500
# Processed batch 131/1975 of size 500
# Processed batch 132/1975 of size 500
# Processed batch 133/1975 of size 500
# Processed batch 134/1975 of size 500
# Processed batch 135/1975 of size 500
# Processed batch 136/1975 of size 500
# Processed batch 137/1975 of size 500
# Processed batch 138/1975 of size 500
# Processed batch 139/1975 of size 500
# Processed batch 140/1975 of size 500
# Processed batch 141/1975 of size 500
# Processed batch 142/1975 of size 500
# Processed batch 143/1975 of size 500
# Processed batch 144/1975 of size 500
# Processed batch 145/1975 of size 500
# Processed batch 146/1975 of size 500
# Processed batch 147/1975 of size 500
# Processed batch 148/1975 of size 500
# Processed batch 149/1975 of size 500
# Processed batch 150/1975 of size 500
# Processed batch 151/1975 of size 500
# Processed batch 152/1975 of size 500
# Processed batch 153/1975 of size 500
# Processed batch 154/1975 of size 500
# Processed batch 155/1975 of size 500
# Processed batch 156/1975 of size 500
# Processed batch 157/1975 of size 500
# Processed batch 158/1975 of size 500
# Processed batch 159/1975 of size 500
# Processed batch 160/1975 of size 500
# Processed batch 161/1975 of size 500
# Processed batch 162/1975 of size 500
# Processed batch 163/1975 of size 500
# Processed batch 164/1975 of size 500
# Processed batch 165/1975 of size 500
# Processed batch 166/1975 of size 500
# Processed batch 167/1975 of size 500
# Processed batch 168/1975 of size 500
# Processed batch 169/1975 of size 500
# Processed batch 170/1975 of size 500
# Processed batch 171/1975 of size 500
# Processed batch 172/1975 of size 500
# Processed batch 173/1975 of size 500
# Processed batch 174/1975 of size 500
# Processed batch 175/1975 of size 500
# Processed batch 176/1975 of size 500
# Processed batch 177/1975 of size 500
# Processed batch 178/1975 of size 500
# Processed batch 179/1975 of size 500
# Processed batch 180/1975 of size 500
# Processed batch 181/1975 of size 500
# Processed batch 182/1975 of size 500
# Processed batch 183/1975 of size 500
# Processed batch 184/1975 of size 500
# Processed batch 185/1975 of size 500
# Processed batch 186/1975 of size 500
# Processed batch 187/1975 of size 500
# Processed batch 188/1975 of size 500
# Processed batch 189/1975 of size 500
# Processed batch 190/1975 of size 500
# Processed batch 191/1975 of size 500
# Processed batch 192/1975 of size 500
# Processed batch 193/1975 of size 500
# Processed batch 194/1975 of size 500
# Processed batch 195/1975 of size 500
# Processed batch 196/1975 of size 500
# Processed batch 197/1975 of size 500
# Processed batch 198/1975 of size 500
# Processed batch 199/1975 of size 500
# Processed batch 200/1975 of size 500
# Processed batch 201/1975 of size 500
# Processed batch 202/1975 of size 500
# Processed batch 203/1975 of size 500
# Processed batch 204/1975 of size 500
# Processed batch 205/1975 of size 500
# Processed batch 206/1975 of size 500
# Processed batch 207/1975 of size 500
# Processed batch 208/1975 of size 500
# Processed batch 209/1975 of size 500
# Processed batch 210/1975 of size 500
# Processed batch 211/1975 of size 500
# Processed batch 212/1975 of size 500
# Processed batch 213/1975 of size 500
# Processed batch 214/1975 of size 500
# Processed batch 215/1975 of size 500
# Processed batch 216/1975 of size 500
# Processed batch 217/1975 of size 500
# Processed batch 218/1975 of size 500
# Processed batch 219/1975 of size 500
# Processed batch 220/1975 of size 500
# Processed batch 221/1975 of size 500
# Processed batch 222/1975 of size 500
# Processed batch 223/1975 of size 500
# Processed batch 224/1975 of size 500
# Processed batch 225/1975 of size 500
# Processed batch 226/1975 of size 500
# Processed batch 227/1975 of size 500
# Processed batch 228/1975 of size 500
# Processed batch 229/1975 of size 500
# Processed batch 230/1975 of size 500
# Processed batch 231/1975 of size 500
# Processed batch 232/1975 of size 500
# Processed batch 233/1975 of size 500
# Processed batch 234/1975 of size 500
# Processed batch 235/1975 of size 500
# Processed batch 236/1975 of size 500
# Processed batch 237/1975 of size 500
# Processed batch 238/1975 of size 500
# Processed batch 239/1975 of size 500
# Processed batch 240/1975 of size 500
# Processed batch 241/1975 of size 500
# Processed batch 242/1975 of size 500
# Processed batch 243/1975 of size 500
# Processed batch 244/1975 of size 500
# Processed batch 245/1975 of size 500
# Processed batch 246/1975 of size 500
# Processed batch 247/1975 of size 500
# Processed batch 248/1975 of size 500
# Processed batch 249/1975 of size 500
# Processed batch 250/1975 of size 500
# Processed batch 251/1975 of size 500
# Processed batch 252/1975 of size 500
# Processed batch 253/1975 of size 500
# Processed batch 254/1975 of size 500
# Processed batch 255/1975 of size 500
# Processed batch 256/1975 of size 500
# Processed batch 257/1975 of size 500
# Processed batch 258/1975 of size 500
# Processed batch 259/1975 of size 500
# Processed batch 260/1975 of size 500
# Processed batch 261/1975 of size 500
# Processed batch 262/1975 of size 500
# Processed batch 263/1975 of size 500
# Processed batch 264/1975 of size 500
# Processed batch 265/1975 of size 500
# Processed batch 266/1975 of size 500
# Processed batch 267/1975 of size 500
# Processed batch 268/1975 of size 500
# Processed batch 269/1975 of size 500
# Processed batch 270/1975 of size 500
# Processed batch 271/1975 of size 500
# Processed batch 272/1975 of size 500
# Processed batch 273/1975 of size 500
# Processed batch 274/1975 of size 500
# Processed batch 275/1975 of size 500
# Processed batch 276/1975 of size 500
# Processed batch 277/1975 of size 500
# Processed batch 278/1975 of size 500
# Processed batch 279/1975 of size 500
# Processed batch 280/1975 of size 500
# Processed batch 281/1975 of size 500
# Processed batch 282/1975 of size 500
# Processed batch 283/1975 of size 500
# Processed batch 284/1975 of size 500
# Processed batch 285/1975 of size 500
# Processed batch 286/1975 of size 500
# Processed batch 287/1975 of size 500
# Processed batch 288/1975 of size 500
# Processed batch 289/1975 of size 500
# Processed batch 290/1975 of size 500
# Processed batch 291/1975 of size 500
# Processed batch 292/1975 of size 500
# Processed batch 293/1975 of size 500
# Processed batch 294/1975 of size 500
# Processed batch 295/1975 of size 500
# Processed batch 296/1975 of size 500
# Processed batch 297/1975 of size 500
# Processed batch 298/1975 of size 500
# Processed batch 299/1975 of size 500
# Processed batch 300/1975 of size 500
# Processed batch 301/1975 of size 500
# Processed batch 302/1975 of size 500
# Processed batch 303/1975 of size 500
# Processed batch 304/1975 of size 500
# Processed batch 305/1975 of size 500
# Processed batch 306/1975 of size 500
# Processed batch 307/1975 of size 500
# Processed batch 308/1975 of size 500
# Processed batch 309/1975 of size 500
# Processed batch 310/1975 of size 500
# Processed batch 311/1975 of size 500
# Processed batch 312/1975 of size 500
# Processed batch 313/1975 of size 500
# Processed batch 314/1975 of size 500
# Processed batch 315/1975 of size 500
# Processed batch 316/1975 of size 500
# Processed batch 317/1975 of size 500
# Processed batch 318/1975 of size 500
# Processed batch 319/1975 of size 500
# Processed batch 320/1975 of size 500
# Processed batch 321/1975 of size 500
# Processed batch 322/1975 of size 500
# Processed batch 323/1975 of size 500
# Processed batch 324/1975 of size 500
# Processed batch 325/1975 of size 500
# Processed batch 326/1975 of size 500
# Processed batch 327/1975 of size 500
# Processed batch 328/1975 of size 500
# Processed batch 329/1975 of size 500
# Processed batch 330/1975 of size 500
# Processed batch 331/1975 of size 500
# Processed batch 332/1975 of size 500
# Processed batch 333/1975 of size 500
# Processed batch 334/1975 of size 500
# Processed batch 335/1975 of size 500
# Processed batch 336/1975 of size 500
# Processed batch 337/1975 of size 500
# Processed batch 338/1975 of size 500
# Processed batch 339/1975 of size 500
# Processed batch 340/1975 of size 500
# Processed batch 341/1975 of size 500
# Processed batch 342/1975 of size 500
# Processed batch 343/1975 of size 500
# Processed batch 344/1975 of size 500
# Processed batch 345/1975 of size 500
# Processed batch 346/1975 of size 500
# Processed batch 347/1975 of size 500
# Processed batch 348/1975 of size 500
# Processed batch 349/1975 of size 500
# Processed batch 350/1975 of size 500
# Processed batch 351/1975 of size 500
# Processed batch 352/1975 of size 500
# Processed batch 353/1975 of size 500
# Processed batch 354/1975 of size 500
# Processed batch 355/1975 of size 500
# Processed batch 356/1975 of size 500
# Processed batch 357/1975 of size 500
# Processed batch 358/1975 of size 500
# Processed batch 359/1975 of size 500
# Processed batch 360/1975 of size 500
# Processed batch 361/1975 of size 500
# Processed batch 362/1975 of size 500
# Processed batch 363/1975 of size 500
# Processed batch 411/1975 of size 500
# Processed batch 412/1975 of size 500
# Processed batch 413/1975 of size 500
# Processed batch 414/1975 of size 500
# Processed batch 415/1975 of size 500
# Processed batch 416/1975 of size 500
# Processed batch 417/1975 of size 500
# Processed batch 418/1975 of size 500
# Processed batch 419/1975 of size 500
# Processed batch 420/1975 of size 500
# Processed batch 421/1975 of size 500
# Processed batch 422/1975 of size 500
# Processed batch 423/1975 of size 500
# Processed batch 424/1975 of size 500
# Processed batch 425/1975 of size 500
# Processed batch 426/1975 of size 500
# Processed batch 427/1975 of size 500
# Processed batch 428/1975 of size 500
# Processed batch 429/1975 of size 500
# Processed batch 430/1975 of size 500
# Processed batch 431/1975 of size 500
# Processed batch 432/1975 of size 500
# Processed batch 433/1975 of size 500
# Processed batch 434/1975 of size 500
# Processed batch 435/1975 of size 500
# Processed batch 436/1975 of size 500
# Processed batch 437/1975 of size 500
# Processed batch 438/1975 of size 500
# Processed batch 439/1975 of size 500
# Processed batch 440/1975 of size 500
# Processed batch 441/1975 of size 500
# Processed batch 442/1975 of size 500
# Processed batch 443/1975 of size 500
# Processed batch 444/1975 of size 500
# Processed batch 445/1975 of size 500
# Processed batch 446/1975 of size 500
# Processed batch 447/1975 of size 500
# Processed batch 448/1975 of size 500
# Processed batch 449/1975 of size 500
# Processed batch 450/1975 of size 500
# Processed batch 451/1975 of size 500
# Processed batch 452/1975 of size 500
# Processed batch 453/1975 of size 500
# Processed batch 454/1975 of size 500
# Processed batch 455/1975 of size 500
# Processed batch 456/1975 of size 500
# Processed batch 457/1975 of size 500
# Processed batch 458/1975 of size 500
# Processed batch 459/1975 of size 500
# Processed batch 460/1975 of size 500
# Processed batch 461/1975 of size 500
# Processed batch 462/1975 of size 500
# Processed batch 463/1975 of size 500
# Processed batch 464/1975 of size 500
# Processed batch 465/1975 of size 500
# Processed batch 466/1975 of size 500
# Processed batch 467/1975 of size 500
# Processed batch 468/1975 of size 500
# Processed batch 469/1975 of size 500
# Processed batch 470/1975 of size 500
# Processed batch 471/1975 of size 500
# Processed batch 472/1975 of size 500
# Processed batch 473/1975 of size 500
# Processed batch 474/1975 of size 500
# Processed batch 475/1975 of size 500
# Processed batch 476/1975 of size 500
# Processed batch 477/1975 of size 500
# Processed batch 478/1975 of size 500
# Processed batch 479/1975 of size 500
# Processed batch 480/1975 of size 500
# Processed batch 481/1975 of size 500
# Processed batch 482/1975 of size 500
# Processed batch 483/1975 of size 500
# Processed batch 484/1975 of size 500
# Processed batch 485/1975 of size 500
# Processed batch 486/1975 of size 500
# Processed batch 487/1975 of size 500
# Processed batch 488/1975 of size 500
# Processed batch 489/1975 of size 500
# Processed batch 490/1975 of size 500
# Processed batch 491/1975 of size 500
# Processed batch 492/1975 of size 500
# Processed batch 493/1975 of size 500
# Processed batch 494/1975 of size 500
# Processed batch 495/1975 of size 500
# Processed batch 496/1975 of size 500
# Processed batch 497/1975 of size 500
# Processed batch 498/1975 of size 500
# Processed batch 499/1975 of size 500
# Processed batch 500/1975 of size 500
# Processed batch 501/1975 of size 500
# Processed batch 502/1975 of size 500
# Processed batch 503/1975 of size 500
# Processed batch 504/1975 of size 500
# Processed batch 505/1975 of size 500
# Processed batch 506/1975 of size 500
# Processed batch 507/1975 of size 500
# Processed batch 508/1975 of size 500
# Processed batch 509/1975 of size 500
# Processed batch 510/1975 of size 500
# Processed batch 511/1975 of size 500
# Processed batch 512/1975 of size 500
# Processed batch 513/1975 of size 500
# Processed batch 514/1975 of size 500
# Processed batch 515/1975 of size 500
# Processed batch 516/1975 of size 500
# Processed batch 517/1975 of size 500
# Processed batch 518/1975 of size 500
# Processed batch 519/1975 of size 500
# Processed batch 520/1975 of size 500
# Processed batch 521/1975 of size 500
# Processed batch 522/1975 of size 500
# Processed batch 523/1975 of size 500
# Processed batch 524/1975 of size 500
# Processed batch 525/1975 of size 500
# Processed batch 526/1975 of size 500
# Processed batch 527/1975 of size 500
# Processed batch 528/1975 of size 500
# Processed batch 529/1975 of size 500
# Processed batch 530/1975 of size 500
# Processed batch 531/1975 of size 500
# Processed batch 532/1975 of size 500
# Processed batch 533/1975 of size 500
# Processed batch 534/1975 of size 500
# Processed batch 535/1975 of size 500
# Processed batch 536/1975 of size 500
# Processed batch 537/1975 of size 500
# Processed batch 538/1975 of size 500
# Processed batch 539/1975 of size 500
# Processed batch 540/1975 of size 500
# Processed batch 541/1975 of size 500
# Processed batch 542/1975 of size 500
# Processed batch 543/1975 of size 500
# Processed batch 544/1975 of size 500
# Processed batch 545/1975 of size 500
# Processed batch 546/1975 of size 500
# Processed batch 547/1975 of size 500
# Processed batch 548/1975 of size 500
# Processed batch 549/1975 of size 500
# Processed batch 550/1975 of size 500
# Processed batch 551/1975 of size 500
# Processed batch 552/1975 of size 500
# Processed batch 553/1975 of size 500
# Processed batch 554/1975 of size 500
# Processed batch 555/1975 of size 500
# Processed batch 556/1975 of size 500
# Processed batch 557/1975 of size 500
# Processed batch 558/1975 of size 500
# Processed batch 559/1975 of size 500
# Processed batch 560/1975 of size 500
# Processed batch 561/1975 of size 500
# Processed batch 562/1975 of size 500
# Processed batch 563/1975 of size 500
# Processed batch 564/1975 of size 500
# Processed batch 565/1975 of size 500
# Processed batch 566/1975 of size 500
# Processed batch 567/1975 of size 500
# Processed batch 568/1975 of size 500
# Processed batch 569/1975 of size 500
# Processed batch 570/1975 of size 500
# Processed batch 571/1975 of size 500
# Processed batch 572/1975 of size 500
# Processed batch 573/1975 of size 500
# Processed batch 574/1975 of size 500
# Processed batch 575/1975 of size 500
# Processed batch 576/1975 of size 500
# Processed batch 577/1975 of size 500
# Processed batch 578/1975 of size 500
# Processed batch 579/1975 of size 500
# Processed batch 580/1975 of size 500
# Processed batch 581/1975 of size 500
# Processed batch 582/1975 of size 500
# Processed batch 583/1975 of size 500
# Processed batch 584/1975 of size 500
# Processed batch 585/1975 of size 500
# Processed batch 586/1975 of size 500
# Processed batch 587/1975 of size 500
# Processed batch 588/1975 of size 500
# Processed batch 589/1975 of size 500
# Processed batch 590/1975 of size 500
# Processed batch 591/1975 of size 500
# Processed batch 592/1975 of size 500
# Processed batch 593/1975 of size 500
# Processed batch 594/1975 of size 500
# Processed batch 595/1975 of size 500
# Processed batch 596/1975 of size 500
# Processed batch 597/1975 of size 500
# Processed batch 598/1975 of size 500
# Processed batch 599/1975 of size 500
# Processed batch 600/1975 of size 500
# Processed batch 601/1975 of size 500
# Processed batch 602/1975 of size 500
# Processed batch 603/1975 of size 500
# Processed batch 604/1975 of size 500
# Processed batch 605/1975 of size 500
# Processed batch 606/1975 of size 500
# Processed batch 607/1975 of size 500
# Processed batch 608/1975 of size 500
# Processed batch 609/1975 of size 500
# Processed batch 610/1975 of size 500
# Processed batch 611/1975 of size 500
# Processed batch 612/1975 of size 500
# Processed batch 613/1975 of size 500
# Processed batch 614/1975 of size 500
# Processed batch 615/1975 of size 500
# Processed batch 616/1975 of size 500
# Processed batch 617/1975 of size 500
# Processed batch 618/1975 of size 500
# Processed batch 619/1975 of size 500
# Processed batch 620/1975 of size 500
# Processed batch 621/1975 of size 500
# Processed batch 622/1975 of size 500
# Processed batch 623/1975 of size 500
# Processed batch 624/1975 of size 500
# Processed batch 625/1975 of size 500
# Processed batch 626/1975 of size 500
# Processed batch 627/1975 of size 500
# Processed batch 628/1975 of size 500
# Processed batch 629/1975 of size 500
# Processed batch 630/1975 of size 500
# Processed batch 631/1975 of size 500
# Processed batch 632/1975 of size 500
# Processed batch 633/1975 of size 500
# Processed batch 634/1975 of size 500
# Processed batch 635/1975 of size 500
# Processed batch 636/1975 of size 500
# Processed batch 637/1975 of size 500
# Processed batch 638/1975 of size 500
# Processed batch 639/1975 of size 500
# Processed batch 640/1975 of size 500
# Processed batch 641/1975 of size 500
# Processed batch 642/1975 of size 500
# Processed batch 643/1975 of size 500
# Processed batch 644/1975 of size 500
# Processed batch 645/1975 of size 500
# Processed batch 646/1975 of size 500
# Processed batch 647/1975 of size 500
# Processed batch 648/1975 of size 500
# Processed batch 649/1975 of size 500
# Processed batch 650/1975 of size 500
# Processed batch 651/1975 of size 500
# Processed batch 652/1975 of size 500
# Processed batch 653/1975 of size 500
# Processed batch 654/1975 of size 500
# Processed batch 655/1975 of size 500
# Processed batch 656/1975 of size 500
# Processed batch 657/1975 of size 500
# Processed batch 658/1975 of size 500
# Processed batch 659/1975 of size 500
# Processed batch 660/1975 of size 500
# Processed batch 661/1975 of size 500
# Processed batch 662/1975 of size 500
# Processed batch 663/1975 of size 500
# Processed batch 664/1975 of size 500
# Processed batch 665/1975 of size 500
# Processed batch 666/1975 of size 500
# Processed batch 667/1975 of size 500
# Processed batch 668/1975 of size 500
# Processed batch 669/1975 of size 500
# Processed batch 670/1975 of size 500
# Processed batch 671/1975 of size 500
# Processed batch 672/1975 of size 500
# Processed batch 673/1975 of size 500
# Processed batch 674/1975 of size 500
# Processed batch 675/1975 of size 500
# Processed batch 676/1975 of size 500
# Processed batch 677/1975 of size 500
# Processed batch 678/1975 of size 500
# Processed batch 679/1975 of size 500
# Processed batch 680/1975 of size 500
# Processed batch 681/1975 of size 500
# Processed batch 682/1975 of size 500
# Processed batch 683/1975 of size 500
# Processed batch 684/1975 of size 500
# Processed batch 685/1975 of size 500
# Processed batch 686/1975 of size 500
# Processed batch 687/1975 of size 500
# Processed batch 688/1975 of size 500
# Processed batch 689/1975 of size 500
# Processed batch 690/1975 of size 500
# Processed batch 691/1975 of size 500
# Processed batch 692/1975 of size 500
# Processed batch 693/1975 of size 500
# Processed batch 694/1975 of size 500
# Processed batch 695/1975 of size 500
# Processed batch 696/1975 of size 500
# Processed batch 697/1975 of size 500
# Processed batch 698/1975 of size 500
# Processed batch 699/1975 of size 500
# Processed batch 700/1975 of size 500
# Processed batch 701/1975 of size 500
# Processed batch 702/1975 of size 500
# Processed batch 703/1975 of size 500
# Processed batch 704/1975 of size 500
# Processed batch 705/1975 of size 500
# Processed batch 706/1975 of size 500
# Processed batch 707/1975 of size 500
# Processed batch 708/1975 of size 500
# Processed batch 709/1975 of size 500
# Processed batch 710/1975 of size 500
# Processed batch 711/1975 of size 500
# Processed batch 712/1975 of size 500
# Processed batch 713/1975 of size 500
# Processed batch 714/1975 of size 500
# Processed batch 715/1975 of size 500
# Processed batch 716/1975 of size 500
# Processed batch 717/1975 of size 500
# Processed batch 718/1975 of size 500
# Processed batch 719/1975 of size 500
# Processed batch 720/1975 of size 500
# Processed batch 721/1975 of size 500
# Processed batch 722/1975 of size 500
# Processed batch 723/1975 of size 500
# Processed batch 724/1975 of size 500
# Processed batch 725/1975 of size 500
# Processed batch 726/1975 of size 500
# Processed batch 727/1975 of size 500
# Processed batch 728/1975 of size 500
# Processed batch 729/1975 of size 500
# Processed batch 730/1975 of size 500
# Processed batch 731/1975 of size 500
# Processed batch 732/1975 of size 500
# Processed batch 733/1975 of size 500
# Processed batch 734/1975 of size 500
# Processed batch 735/1975 of size 500
# Processed batch 736/1975 of size 500
# Processed batch 737/1975 of size 500
# Processed batch 738/1975 of size 500
# Processed batch 739/1975 of size 500
# Processed batch 740/1975 of size 500
# Processed batch 741/1975 of size 500
# Processed batch 742/1975 of size 500
# Processed batch 743/1975 of size 500
# Processed batch 744/1975 of size 500
# Processed batch 745/1975 of size 500
# Processed batch 746/1975 of size 500
# Processed batch 747/1975 of size 500
# Processed batch 748/1975 of size 500
# Processed batch 749/1975 of size 500
# Processed batch 750/1975 of size 500
# Processed batch 751/1975 of size 500
# Processed batch 752/1975 of size 500
# Processed batch 753/1975 of size 500
# Processed batch 754/1975 of size 500
# Processed batch 755/1975 of size 500
# Processed batch 756/1975 of size 500
# Processed batch 757/1975 of size 500
# Processed batch 758/1975 of size 500
# Processed batch 759/1975 of size 500
# Processed batch 760/1975 of size 500
# Processed batch 761/1975 of size 500
# Processed batch 762/1975 of size 500
# Processed batch 763/1975 of size 500
# Processed batch 764/1975 of size 500
# Processed batch 765/1975 of size 500
# Processed batch 766/1975 of size 500
# Processed batch 767/1975 of size 500
# Processed batch 768/1975 of size 500
# Processed batch 769/1975 of size 500
# Processed batch 770/1975 of size 500
# Processed batch 771/1975 of size 500
# Processed batch 772/1975 of size 500
# Processed batch 773/1975 of size 500
# Processed batch 774/1975 of size 500
# Processed batch 775/1975 of size 500
# Processed batch 776/1975 of size 500
# Processed batch 777/1975 of size 500
# Processed batch 778/1975 of size 500
# Processed batch 779/1975 of size 500
# Processed batch 780/1975 of size 500
# Processed batch 781/1975 of size 500
# Processed batch 782/1975 of size 500
# Processed batch 783/1975 of size 500
# Processed batch 784/1975 of size 500
# Processed batch 785/1975 of size 500
# Processed batch 786/1975 of size 500
# Processed batch 787/1975 of size 500
# Processed batch 788/1975 of size 500
# Processed batch 789/1975 of size 500
# Processed batch 790/1975 of size 500
# Processed batch 791/1975 of size 500
# Processed batch 792/1975 of size 500
# Processed batch 793/1975 of size 500
# Processed batch 794/1975 of size 500
# Processed batch 795/1975 of size 500
# Processed batch 796/1975 of size 500
# Processed batch 797/1975 of size 500
# Processed batch 798/1975 of size 500
# Processed batch 799/1975 of size 500
# Processed batch 800/1975 of size 500
# Processed batch 801/1975 of size 500
# Processed batch 802/1975 of size 500
# Processed batch 803/1975 of size 500
# Processed batch 804/1975 of size 500
# Processed batch 805/1975 of size 500
# Processed batch 806/1975 of size 500
# Processed batch 807/1975 of size 500
# Processed batch 808/1975 of size 500
# Processed batch 809/1975 of size 500
# Processed batch 810/1975 of size 500
# Processed batch 811/1975 of size 500
# Processed batch 812/1975 of size 500
# Processed batch 813/1975 of size 500
# Processed batch 814/1975 of size 500
# Processed batch 815/1975 of size 500
# Processed batch 816/1975 of size 500
# Processed batch 817/1975 of size 500
# Processed batch 818/1975 of size 500
# Processed batch 819/1975 of size 500
# Processed batch 820/1975 of size 500
# Processed batch 821/1975 of size 500
# Processed batch 822/1975 of size 500
# Processed batch 823/1975 of size 500
# Processed batch 824/1975 of size 500
# Processed batch 825/1975 of size 500
# Processed batch 826/1975 of size 500
# Processed batch 827/1975 of size 500
# Processed batch 828/1975 of size 500
# Processed batch 829/1975 of size 500
# Processed batch 830/1975 of size 500
# Processed batch 831/1975 of size 500
# Processed batch 832/1975 of size 500
# Processed batch 833/1975 of size 500
# Processed batch 834/1975 of size 500
# Processed batch 835/1975 of size 500
# Processed batch 836/1975 of size 500
# Processed batch 837/1975 of size 500
# Processed batch 838/1975 of size 500
# Processed batch 839/1975 of size 500
# Processed batch 840/1975 of size 500
# Processed batch 841/1975 of size 500
# Processed batch 842/1975 of size 500
# Processed batch 843/1975 of size 500
# Processed batch 844/1975 of size 500
# Processed batch 845/1975 of size 500
# Processed batch 846/1975 of size 500
# Processed batch 847/1975 of size 500
# Processed batch 848/1975 of size 500
# Processed batch 849/1975 of size 500
# Processed batch 850/1975 of size 500
# Processed batch 851/1975 of size 500
# Processed batch 852/1975 of size 500
# Processed batch 853/1975 of size 500
# Processed batch 854/1975 of size 500
# Processed batch 855/1975 of size 500
# Processed batch 856/1975 of size 500
# Processed batch 857/1975 of size 500
# Processed batch 858/1975 of size 500
# Processed batch 859/1975 of size 500
# Processed batch 860/1975 of size 500
# Processed batch 861/1975 of size 500
# Processed batch 862/1975 of size 500
# Processed batch 863/1975 of size 500
# Processed batch 864/1975 of size 500
# Processed batch 865/1975 of size 500
# Processed batch 866/1975 of size 500
# Processed batch 867/1975 of size 500
# Processed batch 868/1975 of size 500
# Processed batch 869/1975 of size 500
# Processed batch 870/1975 of size 500
# Processed batch 871/1975 of size 500
# Processed batch 872/1975 of size 500
# Processed batch 873/1975 of size 500
# Processed batch 874/1975 of size 500
# Processed batch 875/1975 of size 500
# Processed batch 876/1975 of size 500
# Processed batch 877/1975 of size 500
# Processed batch 878/1975 of size 500
# Processed batch 879/1975 of size 500
# Processed batch 880/1975 of size 500
# Processed batch 881/1975 of size 500
# Processed batch 882/1975 of size 500
# Processed batch 883/1975 of size 500
# Processed batch 884/1975 of size 500
# Processed batch 885/1975 of size 500
# Processed batch 886/1975 of size 500
# Processed batch 887/1975 of size 500
# Processed batch 888/1975 of size 500
# Processed batch 889/1975 of size 500
# Processed batch 890/1975 of size 500
# Processed batch 891/1975 of size 500
# Processed batch 892/1975 of size 500
# Processed batch 893/1975 of size 500
# Processed batch 894/1975 of size 500
# Processed batch 895/1975 of size 500
# Processed batch 896/1975 of size 500
# Processed batch 897/1975 of size 500
# Processed batch 898/1975 of size 500
# Processed batch 899/1975 of size 500
# Processed batch 900/1975 of size 500
# Processed batch 901/1975 of size 500
# Processed batch 902/1975 of size 500
# Processed batch 903/1975 of size 500
# Processed batch 904/1975 of size 500
# Processed batch 905/1975 of size 500
# Processed batch 906/1975 of size 500
# Processed batch 907/1975 of size 500
# Processed batch 908/1975 of size 500
# Processed batch 909/1975 of size 500
# Processed batch 910/1975 of size 500
# Processed batch 911/1975 of size 500
# Processed batch 912/1975 of size 500
# Processed batch 913/1975 of size 500
# Processed batch 914/1975 of size 500
# Processed batch 915/1975 of size 500
# Processed batch 916/1975 of size 500
# Processed batch 917/1975 of size 500
# Processed batch 918/1975 of size 500
# Processed batch 919/1975 of size 500
# Processed batch 920/1975 of size 500
# Processed batch 921/1975 of size 500
# Processed batch 922/1975 of size 500
# Processed batch 923/1975 of size 500
# Processed batch 924/1975 of size 500
# Processed batch 925/1975 of size 500
# Processed batch 926/1975 of size 500
# Processed batch 927/1975 of size 500
# Processed batch 928/1975 of size 500
# Processed batch 929/1975 of size 500
# Processed batch 930/1975 of size 500
# Processed batch 931/1975 of size 500
# Processed batch 932/1975 of size 500
# Processed batch 933/1975 of size 500
# Processed batch 934/1975 of size 500
# Processed batch 935/1975 of size 500
# Processed batch 936/1975 of size 500
# Processed batch 937/1975 of size 500
# Processed batch 938/1975 of size 500
# Processed batch 939/1975 of size 500
# Processed batch 940/1975 of size 500
# Processed batch 941/1975 of size 500
# Processed batch 942/1975 of size 500
# Processed batch 943/1975 of size 500
# Processed batch 944/1975 of size 500
# Processed batch 945/1975 of size 500
# Processed batch 946/1975 of size 500
# Processed batch 947/1975 of size 500
# Processed batch 948/1975 of size 500
# Processed batch 949/1975 of size 500
# Processed batch 950/1975 of size 500
# Processed batch 951/1975 of size 500
# Processed batch 952/1975 of size 500
# Processed batch 953/1975 of size 500
# Processed batch 954/1975 of size 500
# Processed batch 955/1975 of size 500
# Processed batch 956/1975 of size 500
# Processed batch 957/1975 of size 500
# Processed batch 958/1975 of size 500
# Processed batch 959/1975 of size 500
# Processed batch 960/1975 of size 500
# Processed batch 961/1975 of size 500
# Processed batch 962/1975 of size 500
# Processed batch 963/1975 of size 500
# Processed batch 964/1975 of size 500
# Processed batch 965/1975 of size 500
# Processed batch 966/1975 of size 500
# Processed batch 967/1975 of size 500
# Processed batch 968/1975 of size 500
# Processed batch 969/1975 of size 500
# Processed batch 970/1975 of size 500
# Processed batch 971/1975 of size 500
# Processed batch 972/1975 of size 500
# Processed batch 973/1975 of size 500
# Processed batch 974/1975 of size 500
# Processed batch 975/1975 of size 500
# Processed batch 976/1975 of size 500
# Processed batch 977/1975 of size 500
# Processed batch 978/1975 of size 500
# Processed batch 979/1975 of size 500
# Processed batch 980/1975 of size 500
# Processed batch 981/1975 of size 500
# Processed batch 982/1975 of size 500
# Processed batch 983/1975 of size 500
# Processed batch 984/1975 of size 500
# Processed batch 985/1975 of size 500
# Processed batch 986/1975 of size 500
# Processed batch 987/1975 of size 500
# Processed batch 988/1975 of size 500
# Processed batch 989/1975 of size 500
# Processed batch 990/1975 of size 500
# Processed batch 991/1975 of size 500
# Processed batch 992/1975 of size 500
# Processed batch 993/1975 of size 500
# Processed batch 994/1975 of size 500
# Processed batch 995/1975 of size 500
# Processed batch 996/1975 of size 500
# Processed batch 997/1975 of size 500
# Processed batch 998/1975 of size 500
# Processed batch 999/1975 of size 500
# Processed batch 1000/1975 of size 500
# Processed batch 1001/1975 of size 500
# Processed batch 1002/1975 of size 500
# Processed batch 1003/1975 of size 500
# Processed batch 1004/1975 of size 500
# Processed batch 1005/1975 of size 500
# Processed batch 1006/1975 of size 500
# Processed batch 1007/1975 of size 500
# Processed batch 1008/1975 of size 500
# Processed batch 1009/1975 of size 500
# Processed batch 1010/1975 of size 500
# Processed batch 1011/1975 of size 500
# Processed batch 1012/1975 of size 500
# Processed batch 1013/1975 of size 500
# Processed batch 1014/1975 of size 500
# Processed batch 1015/1975 of size 500
# Processed batch 1016/1975 of size 500
# Processed batch 1017/1975 of size 500
# Processed batch 1018/1975 of size 500
# Processed batch 1019/1975 of size 500
# Processed batch 1020/1975 of size 500
# Processed batch 1021/1975 of size 500
# Processed batch 1022/1975 of size 500
# Processed batch 1023/1975 of size 500
# Processed batch 1024/1975 of size 500
# Processed batch 1025/1975 of size 500
# Processed batch 1026/1975 of size 500
# Processed batch 1027/1975 of size 500
# Processed batch 1028/1975 of size 500
# Processed batch 1029/1975 of size 500
# Processed batch 1030/1975 of size 500
# Processed batch 1031/1975 of size 500
# Processed batch 1032/1975 of size 500
# Processed batch 1033/1975 of size 500
# Processed batch 1034/1975 of size 500
# Processed batch 1035/1975 of size 500
# Processed batch 1036/1975 of size 500
# Processed batch 1037/1975 of size 500
# Processed batch 1038/1975 of size 500
# Processed batch 1039/1975 of size 500
# Processed batch 1040/1975 of size 500
# Processed batch 1041/1975 of size 500
# Processed batch 1042/1975 of size 500
# Processed batch 1043/1975 of size 500
# Processed batch 1044/1975 of size 500
# Processed batch 1045/1975 of size 500
# Processed batch 1046/1975 of size 500
# Processed batch 1047/1975 of size 500
# Processed batch 1048/1975 of size 500
# Processed batch 1049/1975 of size 500
# Processed batch 1050/1975 of size 500
# Processed batch 1051/1975 of size 500
# Processed batch 1052/1975 of size 500
# Processed batch 1053/1975 of size 500
# Processed batch 1054/1975 of size 500
# Processed batch 1055/1975 of size 500
# Processed batch 1056/1975 of size 500
# Processed batch 1057/1975 of size 500
# Processed batch 1058/1975 of size 500
# Processed batch 1059/1975 of size 500
# Processed batch 1060/1975 of size 500
# Processed batch 1061/1975 of size 500
# Processed batch 1062/1975 of size 500
# Processed batch 1063/1975 of size 500
# Processed batch 1064/1975 of size 500
# Processed batch 1065/1975 of size 500
# Processed batch 1066/1975 of size 500
# Processed batch 1067/1975 of size 500
# Processed batch 1068/1975 of size 500
# Processed batch 1069/1975 of size 500
# Processed batch 1070/1975 of size 500
# Processed batch 1071/1975 of size 500
# Processed batch 1072/1975 of size 500
# Processed batch 1073/1975 of size 500
# Processed batch 1074/1975 of size 500
# Processed batch 1075/1975 of size 500
# Processed batch 1076/1975 of size 500
# Processed batch 1077/1975 of size 500
# Processed batch 1078/1975 of size 500
# Processed batch 1079/1975 of size 500
# Processed batch 1080/1975 of size 500
# Processed batch 1081/1975 of size 500
# Processed batch 1082/1975 of size 500
# Processed batch 1083/1975 of size 500
# Processed batch 1084/1975 of size 500
# Processed batch 1085/1975 of size 500
# Processed batch 1086/1975 of size 500
# Processed batch 1087/1975 of size 500
# Processed batch 1088/1975 of size 500
# Processed batch 1089/1975 of size 500
# Processed batch 1090/1975 of size 500
# Processed batch 1091/1975 of size 500
# Processed batch 1092/1975 of size 500
# Processed batch 1093/1975 of size 500
# Processed batch 1094/1975 of size 500
# Processed batch 1095/1975 of size 500
# Processed batch 1096/1975 of size 500
# Processed batch 1097/1975 of size 500
# Processed batch 1098/1975 of size 500
# Processed batch 1099/1975 of size 500
# Processed batch 1100/1975 of size 500
# Processed batch 1101/1975 of size 500
# Processed batch 1102/1975 of size 500
# Processed batch 1103/1975 of size 500
# Processed batch 1104/1975 of size 500
# Processed batch 1105/1975 of size 500
# Processed batch 1106/1975 of size 500
# Processed batch 1107/1975 of size 500
# Processed batch 1108/1975 of size 500
# Processed batch 1109/1975 of size 500
# Processed batch 1110/1975 of size 500
# Processed batch 1111/1975 of size 500
# Processed batch 1112/1975 of size 500
# Processed batch 1113/1975 of size 500
# Processed batch 1114/1975 of size 500
# Processed batch 1115/1975 of size 500
# Processed batch 1116/1975 of size 500
# Processed batch 1117/1975 of size 500
# Processed batch 1118/1975 of size 500
# Processed batch 1119/1975 of size 500
# Processed batch 1120/1975 of size 500
# Processed batch 1121/1975 of size 500
# Processed batch 1122/1975 of size 500
# Processed batch 1123/1975 of size 500
# Processed batch 1124/1975 of size 500
# Processed batch 1125/1975 of size 500
# Processed batch 1126/1975 of size 500
# Processed batch 1127/1975 of size 500
# Processed batch 1128/1975 of size 500
# Processed batch 1129/1975 of size 500
# Processed batch 1130/1975 of size 500
# Processed batch 1131/1975 of size 500
# Processed batch 1132/1975 of size 500
# Processed batch 1133/1975 of size 500
# Processed batch 1134/1975 of size 500
# Processed batch 1135/1975 of size 500
# Processed batch 1136/1975 of size 500
# Processed batch 1137/1975 of size 500
# Processed batch 1138/1975 of size 500
# Processed batch 1139/1975 of size 500
# Processed batch 1140/1975 of size 500
# Processed batch 1141/1975 of size 500
# Processed batch 1142/1975 of size 500
# Processed batch 1143/1975 of size 500
# Processed batch 1144/1975 of size 500
# Processed batch 1145/1975 of size 500
# Processed batch 1146/1975 of size 500
# Processed batch 1147/1975 of size 500
# Processed batch 1148/1975 of size 500
# Processed batch 1149/1975 of size 500
# Processed batch 1150/1975 of size 500
# Processed batch 1151/1975 of size 500
# Processed batch 1152/1975 of size 500
# Processed batch 1153/1975 of size 500
# Processed batch 1154/1975 of size 500
# Processed batch 1155/1975 of size 500
# Processed batch 1156/1975 of size 500
# Processed batch 1157/1975 of size 500
# Processed batch 1158/1975 of size 500
# Processed batch 1159/1975 of size 500
# Processed batch 1160/1975 of size 500
# Processed batch 1161/1975 of size 500
# Processed batch 1162/1975 of size 500
# Processed batch 1163/1975 of size 500
# Processed batch 1164/1975 of size 500
# Processed batch 1165/1975 of size 500
# Processed batch 1166/1975 of size 500
# Processed batch 1167/1975 of size 500
# Processed batch 1168/1975 of size 500
# Processed batch 1169/1975 of size 500
# Processed batch 1170/1975 of size 500
# Processed batch 1171/1975 of size 500
# Processed batch 1172/1975 of size 500
# Processed batch 1173/1975 of size 500
# Processed batch 1174/1975 of size 500
# Processed batch 1175/1975 of size 500
# Processed batch 1176/1975 of size 500
# Processed batch 1177/1975 of size 500
# Processed batch 1178/1975 of size 500
# Processed batch 1179/1975 of size 500
# Processed batch 1180/1975 of size 500
# Processed batch 1181/1975 of size 500
# Processed batch 1182/1975 of size 500
# Processed batch 1183/1975 of size 500
# Processed batch 1184/1975 of size 500
# Processed batch 1185/1975 of size 500
# Processed batch 1186/1975 of size 500
# Processed batch 1187/1975 of size 500
# Processed batch 1188/1975 of size 500
# Processed batch 1189/1975 of size 500
# Processed batch 1190/1975 of size 500
# Processed batch 1191/1975 of size 500
# Processed batch 1192/1975 of size 500
# Processed batch 1193/1975 of size 500
# Processed batch 1194/1975 of size 500
# Processed batch 1195/1975 of size 500
# Processed batch 1196/1975 of size 500
# Processed batch 1197/1975 of size 500
# Processed batch 1198/1975 of size 500
# Processed batch 1199/1975 of size 500
# Processed batch 1200/1975 of size 500
# Processed batch 1201/1975 of size 500
# Processed batch 1202/1975 of size 500
# Processed batch 1203/1975 of size 500
# Processed batch 1204/1975 of size 500
# Processed batch 1205/1975 of size 500
# Processed batch 1206/1975 of size 500
# Processed batch 1207/1975 of size 500
# Processed batch 1208/1975 of size 500
# Processed batch 1209/1975 of size 500
# Processed batch 1210/1975 of size 500
# Processed batch 1211/1975 of size 500
# Processed batch 1212/1975 of size 500
# Processed batch 1213/1975 of size 500
# Processed batch 1214/1975 of size 500
# Processed batch 1215/1975 of size 500
# Processed batch 1216/1975 of size 500
# Processed batch 1217/1975 of size 500
# Processed batch 1218/1975 of size 500
# Processed batch 1219/1975 of size 500
# Processed batch 1220/1975 of size 500
# Processed batch 1221/1975 of size 500
# Processed batch 1222/1975 of size 500
# Processed batch 1223/1975 of size 500
# Processed batch 1224/1975 of size 500
# Processed batch 1225/1975 of size 500
# Processed batch 1226/1975 of size 500
# Processed batch 1227/1975 of size 500
# Processed batch 1228/1975 of size 500
# Processed batch 1229/1975 of size 500
# Processed batch 1230/1975 of size 500
# Processed batch 1231/1975 of size 500
# Processed batch 1232/1975 of size 500
# Processed batch 1233/1975 of size 500
# Processed batch 1234/1975 of size 500
# Processed batch 1235/1975 of size 500
# Processed batch 1236/1975 of size 500
# Processed batch 1237/1975 of size 500
# Processed batch 1238/1975 of size 500
# Processed batch 1239/1975 of size 500
# Processed batch 1240/1975 of size 500
# Processed batch 1241/1975 of size 500
# Processed batch 1242/1975 of size 500
# Processed batch 1243/1975 of size 500
# Processed batch 1244/1975 of size 500
# Processed batch 1245/1975 of size 500
# Processed batch 1246/1975 of size 500
# Processed batch 1247/1975 of size 500
# Processed batch 1248/1975 of size 500
# Processed batch 1249/1975 of size 500
# Processed batch 1250/1975 of size 500
# Processed batch 1251/1975 of size 500
# Processed batch 1252/1975 of size 500
# Processed batch 1253/1975 of size 500
# Processed batch 1254/1975 of size 500
# Processed batch 1255/1975 of size 500
# Processed batch 1256/1975 of size 500
# Processed batch 1257/1975 of size 500
# Processed batch 1258/1975 of size 500
# Processed batch 1259/1975 of size 500
# Processed batch 1260/1975 of size 500
# Processed batch 1261/1975 of size 500
# Processed batch 1262/1975 of size 500
# Processed batch 1263/1975 of size 500
# Processed batch 1264/1975 of size 500
# Processed batch 1265/1975 of size 500
# Processed batch 1266/1975 of size 500
# Processed batch 1267/1975 of size 500
# Processed batch 1268/1975 of size 500
# Processed batch 1269/1975 of size 500
# Processed batch 1270/1975 of size 500
# Processed batch 1271/1975 of size 500
# Processed batch 1272/1975 of size 500
# Processed batch 1273/1975 of size 500
# Processed batch 1274/1975 of size 500
# Processed batch 1275/1975 of size 500
# Processed batch 1276/1975 of size 500
# Processed batch 1277/1975 of size 500
# Processed batch 1278/1975 of size 500
# Processed batch 1279/1975 of size 500
# Processed batch 1280/1975 of size 500
# Processed batch 1281/1975 of size 500
# Processed batch 1282/1975 of size 500
# Processed batch 1283/1975 of size 500
# Processed batch 1284/1975 of size 500
# Processed batch 1285/1975 of size 500
# Processed batch 1286/1975 of size 500
# Processed batch 1287/1975 of size 500
# Processed batch 1288/1975 of size 500
# Processed batch 1289/1975 of size 500
# Processed batch 1290/1975 of size 500
# Processed batch 1291/1975 of size 500
# Processed batch 1292/1975 of size 500
# Processed batch 1293/1975 of size 500
# Processed batch 1294/1975 of size 500
# Processed batch 1295/1975 of size 500
# Processed batch 1296/1975 of size 500
# Processed batch 1297/1975 of size 500
# Processed batch 1298/1975 of size 500
# Processed batch 1299/1975 of size 500
# ...
# Processed batch 1557/1975 of size 500
# Processed batch 1558/1975 of size 500
# Processed batch 1559/1975 of size 500
# Processed batch 1560/1975 of size 500
# Processed batch 1561/1975 of size 500
# Processed batch 1562/1975 of size 500
# Processed batch 1563/1975 of size 500
# Processed batch 1564/1975 of size 500
# Processed batch 1565/1975 of size 500
# Processed batch 1566/1975 of size 500
# Processed batch 1567/1975 of size 500
# Processed batch 1568/1975 of size 500
# Processed batch 1569/1975 of size 500
# Processed batch 1570/1975 of size 500
# Processed batch 1571/1975 of size 500
# Processed batch 1572/1975 of size 500
# Processed batch 1573/1975 of size 500
# Processed batch 1574/1975 of size 500
# Processed batch 1575/1975 of size 500
# Processed batch 1576/1975 of size 500
# Processed batch 1577/1975 of size 500
# Processed batch 1578/1975 of size 500
# Processed batch 1579/1975 of size 500
# Processed batch 1580/1975 of size 500
# Processed batch 1581/1975 of size 500
# Processed batch 1582/1975 of size 500
# Processed batch 1583/1975 of size 500
# Processed batch 1584/1975 of size 500
# Processed batch 1585/1975 of size 500
# Processed batch 1586/1975 of size 500
# Processed batch 1587/1975 of size 500
# Processed batch 1588/1975 of size 500
# Processed batch 1589/1975 of size 500
# Processed batch 1590/1975 of size 500
# Processed batch 1591/1975 of size 500
# Processed batch 1592/1975 of size 500
# Processed batch 1593/1975 of size 500
# Processed batch 1594/1975 of size 500
# Processed batch 1595/1975 of size 500
# Processed batch 1596/1975 of size 500
# Processed batch 1597/1975 of size 500
# Processed batch 1598/1975 of size 500
# Processed batch 1599/1975 of size 500
# Processed batch 1600/1975 of size 500
# Processed batch 1601/1975 of size 500
# Processed batch 1602/1975 of size 500
# Processed batch 1603/1975 of size 500
# Processed batch 1604/1975 of size 500
# Processed batch 1605/1975 of size 500
# Processed batch 1606/1975 of size 500
# Processed batch 1607/1975 of size 500
# Processed batch 1608/1975 of size 500
# Processed batch 1609/1975 of size 500
# Processed batch 1610/1975 of size 500
# Processed batch 1611/1975 of size 500
# Processed batch 1612/1975 of size 500
# Processed batch 1613/1975 of size 500
# Processed batch 1614/1975 of size 500
# Processed batch 1615/1975 of size 500
# Processed batch 1616/1975 of size 500
# Processed batch 1617/1975 of size 500
# Processed batch 1618/1975 of size 500
# Processed batch 1619/1975 of size 500
# Processed batch 1620/1975 of size 500
# Processed batch 1621/1975 of size 500
# Processed batch 1622/1975 of size 500
# Processed batch 1623/1975 of size 500
# Processed batch 1624/1975 of size 500
# Processed batch 1625/1975 of size 500
# Processed batch 1626/1975 of size 500
# Processed batch 1627/1975 of size 500
# Processed batch 1628/1975 of size 500
# Processed batch 1629/1975 of size 500
# Processed batch 1630/1975 of size 500
# Processed batch 1631/1975 of size 500
# Processed batch 1632/1975 of size 500
# Processed batch 1633/1975 of size 500
# Processed batch 1634/1975 of size 500
# Processed batch 1635/1975 of size 500
# Processed batch 1636/1975 of size 500
# Processed batch 1637/1975 of size 500
# Processed batch 1638/1975 of size 500
# Processed batch 1639/1975 of size 500
# Processed batch 1640/1975 of size 500
# Processed batch 1641/1975 of size 500
# Processed batch 1642/1975 of size 500
# Processed batch 1643/1975 of size 500
# Processed batch 1644/1975 of size 500
# Processed batch 1645/1975 of size 500
# Processed batch 1646/1975 of size 500
# Processed batch 1647/1975 of size 500
# Processed batch 1648/1975 of size 500
# Processed batch 1649/1975 of size 500
# Processed batch 1650/1975 of size 500
# Processed batch 1651/1975 of size 500
# Processed batch 1652/1975 of size 500
# Processed batch 1653/1975 of size 500
# Processed batch 1654/1975 of size 500
# Processed batch 1655/1975 of size 500
# Processed batch 1656/1975 of size 500
# Processed batch 1657/1975 of size 500
# Processed batch 1658/1975 of size 500
# Processed batch 1659/1975 of size 500
# Processed batch 1660/1975 of size 500
# Processed batch 1661/1975 of size 500
# Processed batch 1662/1975 of size 500
# Processed batch 1663/1975 of size 500
# Processed batch 1664/1975 of size 500
# Processed batch 1665/1975 of size 500
# Processed batch 1666/1975 of size 500
# Processed batch 1667/1975 of size 500
# Processed batch 1668/1975 of size 500
# Processed batch 1669/1975 of size 500
# Processed batch 1670/1975 of size 500
# Processed batch 1671/1975 of size 500
# Processed batch 1672/1975 of size 500
# Processed batch 1673/1975 of size 500
# Processed batch 1674/1975 of size 500
# Processed batch 1675/1975 of size 500
# Processed batch 1676/1975 of size 500
# Processed batch 1677/1975 of size 500
# Processed batch 1678/1975 of size 500
# Processed batch 1679/1975 of size 500
# Processed batch 1680/1975 of size 500
# Processed batch 1681/1975 of size 500
# Processed batch 1682/1975 of size 500
# Processed batch 1683/1975 of size 500
# Processed batch 1684/1975 of size 500
# Processed batch 1685/1975 of size 500
# Processed batch 1686/1975 of size 500
# Processed batch 1687/1975 of size 500
# Processed batch 1688/1975 of size 500
# Processed batch 1689/1975 of size 500
# Processed batch 1690/1975 of size 500
# Processed batch 1691/1975 of size 500
# Processed batch 1692/1975 of size 500
# Processed batch 1693/1975 of size 500
# Processed batch 1694/1975 of size 500
# Processed batch 1695/1975 of size 500
# Processed batch 1696/1975 of size 500
# Processed batch 1697/1975 of size 500
# Processed batch 1698/1975 of size 500
# Processed batch 1699/1975 of size 500
# Processed batch 1700/1975 of size 500
# Processed batch 1701/1975 of size 500
# Processed batch 1702/1975 of size 500
# Processed batch 1703/1975 of size 500
# Processed batch 1704/1975 of size 500
# Processed batch 1705/1975 of size 500
# Processed batch 1706/1975 of size 500
# Processed batch 1707/1975 of size 500
# Processed batch 1708/1975 of size 500
# Processed batch 1709/1975 of size 500
# Processed batch 1710/1975 of size 500
# Processed batch 1711/1975 of size 500
# Processed batch 1712/1975 of size 500
# Processed batch 1713/1975 of size 500
# Processed batch 1714/1975 of size 500
# Processed batch 1715/1975 of size 500
# Processed batch 1716/1975 of size 500
# Processed batch 1717/1975 of size 500
# Processed batch 1718/1975 of size 500
# Processed batch 1719/1975 of size 500
# Processed batch 1720/1975 of size 500
# Processed batch 1721/1975 of size 500
# Processed batch 1722/1975 of size 500
# Processed batch 1723/1975 of size 500
# Processed batch 1724/1975 of size 500
# Processed batch 1725/1975 of size 500
# Processed batch 1726/1975 of size 500
# Processed batch 1727/1975 of size 500
# Processed batch 1728/1975 of size 500
# Processed batch 1729/1975 of size 500
# Processed batch 1730/1975 of size 500
# Processed batch 1731/1975 of size 500
# Processed batch 1732/1975 of size 500
# Processed batch 1733/1975 of size 500
# Processed batch 1734/1975 of size 500
# Processed batch 1735/1975 of size 500
# Processed batch 1736/1975 of size 500
# Processed batch 1737/1975 of size 500
# Processed batch 1738/1975 of size 500
# Processed batch 1739/1975 of size 500
# Processed batch 1740/1975 of size 500
# Processed batch 1741/1975 of size 500
# Processed batch 1742/1975 of size 500
# Processed batch 1743/1975 of size 500
# Processed batch 1744/1975 of size 500
# Processed batch 1745/1975 of size 500
# Processed batch 1746/1975 of size 500
# Processed batch 1747/1975 of size 500
# Processed batch 1748/1975 of size 500
# Processed batch 1749/1975 of size 500
# Processed batch 1750/1975 of size 500
# Processed batch 1751/1975 of size 500
# Processed batch 1752/1975 of size 500
# Processed batch 1753/1975 of size 500
# Processed batch 1754/1975 of size 500
# Processed batch 1755/1975 of size 500
# Processed batch 1756/1975 of size 500
# Processed batch 1757/1975 of size 500
# Processed batch 1758/1975 of size 500
# Processed batch 1759/1975 of size 500
# Processed batch 1760/1975 of size 500
# Processed batch 1761/1975 of size 500
# Processed batch 1762/1975 of size 500
# Processed batch 1763/1975 of size 500
# Processed batch 1764/1975 of size 500
# Processed batch 1765/1975 of size 500
# Processed batch 1766/1975 of size 500
# Processed batch 1767/1975 of size 500
# Processed batch 1768/1975 of size 500
# Processed batch 1769/1975 of size 500
# Processed batch 1770/1975 of size 500
# Processed batch 1771/1975 of size 500
# Processed batch 1772/1975 of size 500
# Processed batch 1773/1975 of size 500
# Processed batch 1774/1975 of size 500
# Processed batch 1775/1975 of size 500
# Processed batch 1776/1975 of size 500
# Processed batch 1777/1975 of size 500
# Processed batch 1778/1975 of size 500
# Processed batch 1779/1975 of size 500
# Processed batch 1780/1975 of size 500
# Processed batch 1781/1975 of size 500
# Processed batch 1782/1975 of size 500
# Processed batch 1783/1975 of size 500
# Processed batch 1784/1975 of size 500
# Processed batch 1785/1975 of size 500
# Processed batch 1786/1975 of size 500
# Processed batch 1787/1975 of size 500
# Processed batch 1788/1975 of size 500
# Processed batch 1789/1975 of size 500
# Processed batch 1790/1975 of size 500
# Processed batch 1791/1975 of size 500
# Processed batch 1792/1975 of size 500
# Processed batch 1793/1975 of size 500
# Processed batch 1794/1975 of size 500
# Processed batch 1795/1975 of size 500
# Processed batch 1796/1975 of size 500
# Processed batch 1797/1975 of size 500
# Processed batch 1798/1975 of size 500
# Processed batch 1799/1975 of size 500
# Processed batch 1800/1975 of size 500
# Processed batch 1801/1975 of size 500
# Processed batch 1802/1975 of size 500
# Processed batch 1803/1975 of size 500
# Processed batch 1804/1975 of size 500
# Processed batch 1805/1975 of size 500
# Processed batch 1806/1975 of size 500
# Processed batch 1807/1975 of size 500
# Processed batch 1808/1975 of size 500
# Processed batch 1809/1975 of size 500
# Processed batch 1810/1975 of size 500
# Processed batch 1811/1975 of size 500
# Processed batch 1812/1975 of size 500
# Processed batch 1813/1975 of size 500
# Processed batch 1814/1975 of size 500
# Processed batch 1815/1975 of size 500
# Processed batch 1816/1975 of size 500
# Processed batch 1817/1975 of size 500
# Processed batch 1818/1975 of size 500
# Processed batch 1819/1975 of size 500
# Processed batch 1820/1975 of size 500
# Processed batch 1821/1975 of size 500
# Processed batch 1822/1975 of size 500
# Processed batch 1823/1975 of size 500
# Processed batch 1824/1975 of size 500
# Processed batch 1825/1975 of size 500
# Processed batch 1826/1975 of size 500
# Processed batch 1827/1975 of size 500
# Processed batch 1828/1975 of size 500
# Processed batch 1829/1975 of size 500
# Processed batch 1830/1975 of size 500
# Processed batch 1831/1975 of size 500
# Processed batch 1832/1975 of size 500
# Processed batch 1833/1975 of size 500
# Processed batch 1834/1975 of size 500
# Processed batch 1835/1975 of size 500
# Processed batch 1836/1975 of size 500
# Processed batch 1837/1975 of size 500
# Processed batch 1838/1975 of size 500
# Processed batch 1839/1975 of size 500
# Processed batch 1840/1975 of size 500
# Processed batch 1841/1975 of size 500
# Processed batch 1842/1975 of size 500
# Processed batch 1843/1975 of size 500
# Processed batch 1844/1975 of size 500
# Processed batch 1845/1975 of size 500
# Processed batch 1846/1975 of size 500
# Processed batch 1847/1975 of size 500
# Processed batch 1848/1975 of size 500
# Processed batch 1849/1975 of size 500
# Processed batch 1850/1975 of size 500
# Processed batch 1851/1975 of size 500
# Processed batch 1852/1975 of size 500
# Processed batch 1853/1975 of size 500
# Processed batch 1854/1975 of size 500
# Processed batch 1855/1975 of size 500
# Processed batch 1856/1975 of size 500
# Processed batch 1857/1975 of size 500
# Processed batch 1858/1975 of size 500
# Processed batch 1859/1975 of size 500
# Processed batch 1860/1975 of size 500
# Processed batch 1861/1975 of size 500
# Processed batch 1862/1975 of size 500
# Processed batch 1863/1975 of size 500
# Processed batch 1864/1975 of size 500
# Processed batch 1865/1975 of size 500
# Processed batch 1866/1975 of size 500
# Processed batch 1867/1975 of size 500
# Processed batch 1868/1975 of size 500
# Processed batch 1869/1975 of size 500
# Processed batch 1870/1975 of size 500
# Processed batch 1871/1975 of size 500
# Processed batch 1872/1975 of size 500
# Processed batch 1873/1975 of size 500
# Processed batch 1874/1975 of size 500
# Processed batch 1875/1975 of size 500
# Processed batch 1876/1975 of size 500
# Processed batch 1877/1975 of size 500
# Processed batch 1878/1975 of size 500
# Processed batch 1879/1975 of size 500
# Processed batch 1880/1975 of size 500
# Processed batch 1881/1975 of size 500
# Processed batch 1882/1975 of size 500
# Processed batch 1883/1975 of size 500
# Processed batch 1884/1975 of size 500
# Processed batch 1885/1975 of size 500
# Processed batch 1886/1975 of size 500
# Processed batch 1887/1975 of size 500
# Processed batch 1888/1975 of size 500
# Processed batch 1889/1975 of size 500
# Processed batch 1890/1975 of size 500
# Processed batch 1891/1975 of size 500
# Processed batch 1892/1975 of size 500
# Processed batch 1893/1975 of size 500
# Processed batch 1894/1975 of size 500
# Processed batch 1895/1975 of size 500
# Processed batch 1896/1975 of size 500
# Processed batch 1897/1975 of size 500
# Processed batch 1898/1975 of size 500
# Processed batch 1899/1975 of size 500
# Processed batch 1900/1975 of size 500
# Processed batch 1901/1975 of size 500
# Processed batch 1902/1975 of size 500
# Processed batch 1903/1975 of size 500
# Processed batch 1904/1975 of size 500
# Processed batch 1905/1975 of size 500
# Processed batch 1906/1975 of size 500
# Processed batch 1907/1975 of size 500
# Processed batch 1908/1975 of size 500
# Processed batch 1909/1975 of size 500
# Processed batch 1910/1975 of size 500
# Processed batch 1911/1975 of size 500
# Processed batch 1912/1975 of size 500
# Processed batch 1913/1975 of size 500
# Processed batch 1914/1975 of size 500
# Processed batch 1915/1975 of size 500
# Processed batch 1916/1975 of size 500
# Processed batch 1917/1975 of size 500
# Processed batch 1918/1975 of size 500
# Processed batch 1919/1975 of size 500
# Processed batch 1920/1975 of size 500
# Processed batch 1921/1975 of size 500
# Processed batch 1922/1975 of size 500
# Processed batch 1923/1975 of size 500
# Processed batch 1924/1975 of size 500
# Processed batch 1925/1975 of size 500
# Processed batch 1926/1975 of size 500
# Processed batch 1927/1975 of size 500
# Processed batch 1928/1975 of size 500
# Processed batch 1929/1975 of size 500
# Processed batch 1930/1975 of size 500
# Processed batch 1931/1975 of size 500
# Processed batch 1932/1975 of size 500
# Processed batch 1933/1975 of size 500
# Processed batch 1934/1975 of size 500
# Processed batch 1935/1975 of size 500
# Processed batch 1936/1975 of size 500
# Processed batch 1937/1975 of size 500
# Processed batch 1938/1975 of size 500
# Processed batch 1939/1975 of size 500
# Processed batch 1940/1975 of size 500
# Processed batch 1941/1975 of size 500
# Processed batch 1942/1975 of size 500
# Processed batch 1943/1975 of size 500
# Processed batch 1944/1975 of size 500
# Processed batch 1945/1975 of size 500
# Processed batch 1946/1975 of size 500
# Processed batch 1947/1975 of size 500
# Processed batch 1948/1975 of size 500
# Processed batch 1949/1975 of size 500
# Processed batch 1950/1975 of size 500
# Processed batch 1951/1975 of size 500
# Processed batch 1952/1975 of size 500
# Processed batch 1953/1975 of size 500
# Processed batch 1954/1975 of size 500
# Processed batch 1955/1975 of size 500
# Processed batch 1956/1975 of size 500
# Processed batch 1957/1975 of size 500
# Processed batch 1958/1975 of size 500
# Processed batch 1959/1975 of size 500
# Processed batch 1960/1975 of size 500
# Processed batch 1961/1975 of size 500
# Processed batch 1962/1975 of size 500
# Processed batch 1963/1975 of size 500
# Processed batch 1964/1975 of size 500
# Processed batch 1965/1975 of size 500
# Processed batch 1966/1975 of size 500
# Processed batch 1967/1975 of size 500
# Processed batch 1968/1975 of size 500
# Processed batch 1969/1975 of size 500
# Processed batch 1970/1975 of size 500
# Processed batch 1971/1975 of size 500
# Processed batch 1972/1975 of size 500
# Processed batch 1973/1975 of size 500
# Processed batch 1974/1975 of size 500
# Processed batch 1975/1975 of size 122
# Vector store created successfully with FAISS!

# %%
# Sample Python-related questions to test retrieval
query_1 = "How can I reverse a list in Python?"
query_2 = "What is a lambda function in Python?"
query_3 = "How do I handle exceptions in Python?"

# Retrieve top 3 documents for each question
for query in [query_1, query_2, query_3]:
    print(f"Query: {query}\n")
    retrieved_docs = vector_store.similarity_search(query, k=3)  # Retrieve top 3 similar texts
    
    for i, doc in enumerate(retrieved_docs):
        print(f"Retrieved Document {i+1}:\n{doc}\n")
    print("=" * 80)  # Separator between query results
# Out:
# Query: How can I reverse a list in Python?
#
# Retrieved Document 1:
# page_content='How can one reverse the order of a list in Python without using a loop? <p>How can one reverse the order of a list in Python without using a loop? There are no other constraints on the solution space.</p>
#  <p>You can also use the builtin function <code>reversed</code></p>
#
# <pre><code>a = list(reversed(your_list))
# </code></pre>
#  Tags: python list list-comprehension'
#
# Retrieved Document 2:
# page_content='How do I reverse a list using recursion in Python? <p>I want to have a function that will return the reverse of a list that it is given -- using recursion. How can I do that?</p>
#  <p>Take the first element, reverse the rest of the list recursively, and append the first element at the end of the list.</p>
#  Tags: python list recursion'
#
# Retrieved Document 3:
# page_content='How can I reverse a list in python? <p>How can I do this in python?</p>
#
# <pre><code>array = [0,10,20,40]
# for (i = array.length() - 1 ;i &gt;= 0; i--)
# </code></pre>
#
# <p>I need to have the elements of an array but from the end to the beginning.</p>
#  <pre><code>array=[0,10,20,40]
# for e in reversed(array):
#   print e
# </code></pre>
#  Tags: python list'
#
# ================================================================================
# Query: What is a lambda function in Python?
#
# Retrieved Document 1:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>It's an inline anonymous function.</p>
#  Tags: python lambda'
#
# Retrieved Document 2:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>Lambda is more of a concept or programming technique then anything else. </p>
#
# <p>Basically it's the idea that you get a function (a first-class object in python) returned as a result of another function instead of an object or primitive type. I know, it's confusing.</p>
#
# <p>See this example from the <a href="http://docs.python.org/tutorial/controlflow.html#lambda-forms">python documentation</a>: </p>
#
# <pre><code>def make_incrementor(n):
#   return lambda x: x + n
# f = make_incrementor(42)
# f(0)
# &gt;&gt;&gt; 42
# f(1)
# &gt;&gt;&gt; 43
# </code></pre>
#
# <p>So make_incrementor creates a function that uses n in it's results. You could have a function that would increment a parameter by 2 like so: </p>
#
# <pre><code>f2 = make_incrementor(2)
# f2(3)
# &gt;&gt;&gt; 5
# </code></pre>
#
# <p>This is a very powerful idea in functional programming and functional programming languages like lisp &amp; scheme. </p>
#
# <p>Hope this helps.</p>
#  Tags: python lambda'
#
# Retrieved Document 3:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p><code>lambda</code> is a way of defining an anonymous in-line function to accomplish some task versus defining it with the <code>def</code> keyword and calling it. Think of it as a shorthand you can use when you won't need to reuse a function. Anywhere you use lambda, you could substitute an explicitly called function: it's use is completely optional and left to the programmer as a matter of coding style.</p>
#
# <p>Example code (without lambda):</p>
#
# <pre><code>def numSquared(num):
#     return num**2
#
# for i in range(1,11):
#     print numSquared(i)
# </code></pre>
#
# <p>Example code (with lambda):</p>
#
# <pre><code>for i in range(1,11):
#     print (lambda x: x**2)(i)
# </code></pre>
#
# <p>A good beginner's discussion of <code>lambda</code>:
# <a href="http://diveintopython.net/power_of_introspection/lambda_functions.html" rel="nofollow" title="DiveIntoPython - Lambda">DiveIntPython.org - Lambda</a></p>
#  Tags: python lambda'
#
# ================================================================================
# Query: How do I handle exceptions in Python?
#
# Retrieved Document 1:
# page_content='How do I stop a program when an exception is raised in Python? <p>I need to stop my program when an exception is raised in Python.
# How do I implement this?</p>
#  <p>If you don't handle an exception, it will propagate up the call stack up to the interpreter, which will then display a traceback and exit. IOW : you don't have to do <em>anything</em> to make your script exit when an exception happens. </p>
#  Tags: python exception-handling'
#
# Retrieved Document 2:
# page_content='How do I stop a program when an exception is raised in Python? <p>I need to stop my program when an exception is raised in Python.
# How do I implement this?</p>
#  <pre><code>import sys
#
# try:
#   print("stuff")
# except:
#   sys.exit(0)
# </code></pre>
#  Tags: python exception-handling'
#
# Retrieved Document 3:
# page_content='How do I stop a program when an exception is raised in Python? <p>I need to stop my program when an exception is raised in Python.
# How do I implement this?</p>
#  <p>As far as I know, if an exception is not caught by your script, it will be interrupted.</p>
#  Tags: python exception-handling'
#
# ================================================================================

# %%
# !pip install transformers
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Load Flan-T5-base model and tokenizer
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

# Create a text generation pipeline
generation_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer)
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, pipeline

# Load Flan-T5-base model and tokenizer
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base").to("cuda")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

# Create a text generation pipeline, specifying device=0 for GPU usage
generation_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device=0)

# %%
# Step 1: Import necessary libraries
from transformers import T5ForConditionalGeneration, T5Tokenizer, pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain.llms import HuggingFacePipeline

# Step 2: Load Flan-T5-base model and tokenizer on GPU
print("Loading Flan-T5 model and tokenizer...")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base").to("cuda")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

# Step 3: Create a text generation pipeline with GPU support
generation_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device=0)
llm = HuggingFacePipeline(pipeline=generation_pipeline)

# Step 4: Initialize the FAISS vector store and embeddings (assuming `vector_store` is already set up)

# Step 5: Create the ConversationalRetrievalChain for RAG
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=vector_store.as_retriever(),
    return_source_documents=True  # Set to True to include source documents in the response
)

# Step 6: Test the RAG pipeline with a sample Python-related question
print("Starting generation pipeline...")
query = "What is a lambda function in Python?"
chat_history = []  # Initialize an empty chat history for the first question

# Use `invoke` method to get multiple outputs, including the required chat_history
response = qa_chain.invoke({"question": query, "chat_history": chat_history})
answer = response["answer"]  # Extract the generated answer
source_documents = response["source_documents"]  # Extract source documents for context

print(f"Question: {query}")
print(f"Answer: {answer}")
print("Generation completed.")

# Optional: Display the source documents for additional context
for i, doc in enumerate(source_documents):
    print(f"Source Document {i+1}:\n{doc}\n")
# Out:
# Loading Flan-T5 model and tokenizer...
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (1283 > 512). Running this sequence through the model will result in indexing errors
# Starting generation pipeline...
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Question: What is a lambda function in Python?
# Answer: /p>
# Generation completed.
# Source Document 1:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>It's an inline anonymous function.</p>
#  Tags: python lambda'
#
# Source Document 2:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>Lambda is more of a concept or programming technique then anything else. </p>
#
# <p>Basically it's the idea that you get a function (a first-class object in python) returned as a result of another function instead of an object or primitive type. I know, it's confusing.</p>
#
# <p>See this example from the <a href="http://docs.python.org/tutorial/controlflow.html#lambda-forms">python documentation</a>: </p>
#
# <pre><code>def make_incrementor(n):
#   return lambda x: x + n
# f = make_incrementor(42)
# f(0)
# &gt;&gt;&gt; 42
# f(1)
# &gt;&gt;&gt; 43
# </code></pre>
#
# <p>So make_incrementor creates a function that uses n in it's results. You could have a function that would increment a parameter by 2 like so: </p>
#
# <pre><code>f2 = make_incrementor(2)
# f2(3)
# &gt;&gt;&gt; 5
# </code></pre>
#
# <p>This is a very powerful idea in functional programming and functional programming languages like lisp &amp; scheme. </p>
#
# <p>Hope this helps.</p>
#  Tags: python lambda'
#
# Source Document 3:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p><code>lambda</code> is a way of defining an anonymous in-line function to accomplish some task versus defining it with the <code>def</code> keyword and calling it. Think of it as a shorthand you can use when you won't need to reuse a function. Anywhere you use lambda, you could substitute an explicitly called function: it's use is completely optional and left to the programmer as a matter of coding style.</p>
#
# <p>Example code (without lambda):</p>
#
# <pre><code>def numSquared(num):
#     return num**2
#
# for i in range(1,11):
#     print numSquared(i)
# </code></pre>
#
# <p>Example code (with lambda):</p>
#
# <pre><code>for i in range(1,11):
#     print (lambda x: x**2)(i)
# </code></pre>
#
# <p>A good beginner's discussion of <code>lambda</code>:
# <a href="http://diveintopython.net/power_of_introspection/lambda_functions.html" rel="nofollow" title="DiveIntoPython - Lambda">DiveIntPython.org - Lambda</a></p>
#  Tags: python lambda'
#
# Source Document 4:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>Lambdas are not anonymous functions.  Lambdas are anonymous <em>expressions</em>.</p>
#
# <p>They're accessed like functions, but they're not the same thing.  Functions allow complex tasks: flow control, variable declarations and lists of statements containing expressions.  Expressions are merely one part of a function, and that's what lambdas give you.  They're severely limited compared to functions.</p>
#
# <p>Python does not support anonymous functions.  For examples of languages that do, see Javascript and Lua.</p>
#
# <p>(Note: It's correct to call lambdas anonymous functions in functional languages, where the mathematical definition of "function" is used, but in procedural languages the word has a very different meaning than in mathematics.)</p>
#  Tags: python lambda'

# %%
# Import necessary libraries
from transformers import T5ForConditionalGeneration, T5Tokenizer, pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain.llms import HuggingFacePipeline
import re

# Load Flan-T5-base model and tokenizer on GPU
print("Loading Flan-T5 model and tokenizer...")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base").to("cuda")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

# Create a text generation pipeline with max response length control
generation_pipeline = pipeline(
    "text2text-generation", model=model, tokenizer=tokenizer, device=0, max_new_tokens=50
)
llm = HuggingFacePipeline(pipeline=generation_pipeline)

# Initialize the FAISS vector store and embeddings (assuming `vector_store` is already set up)

# Create the ConversationalRetrievalChain for RAG
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=vector_store.as_retriever(),
    return_source_documents=True  # Set to True to include source documents in the response
)

# Clean and truncate function to ensure input within length limits
def clean_and_truncate(text, max_length=200):
    # Remove HTML tags
    text = re.sub(r'<[^>]+>', '', text)
    # Truncate to the model's max input length
    tokens = tokenizer(text, truncation=True, max_length=max_length, return_tensors="pt")
    return tokenizer.decode(tokens["input_ids"][0], skip_special_tokens=True)

# Test the RAG pipeline with a sample Python-related question
print("Starting generation pipeline...")
query = "What is a lambda function in Python?"
chat_history = []  # Initialize an empty chat history for the first question

# Retrieve and process top documents
response = qa_chain.invoke({
    "question": query,
    "chat_history": chat_history
})
# Clean and truncate each document to avoid exceeding token limit
truncated_sources = [{"page_content": clean_and_truncate(doc.page_content, max_length=200)} for doc in response["source_documents"]]

# Generate answer with simplified and truncated input documents
answer_response = qa_chain.invoke({
    "question": query,
    "chat_history": chat_history,
    "source_documents": truncated_sources  # Pass processed and simplified documents
})

answer = answer_response["answer"]  # Extract the generated answer
source_documents = answer_response["source_documents"]  # Extract source documents for context

print(f"Question: {query}")
print(f"Answer: {answer}")
print("Generation completed.")

# Display the cleaned and truncated source documents
for i, doc in enumerate(source_documents):
    print(f"Source Document {i+1}:\n{doc}\n")
# Out:
# Loading Flan-T5 model and tokenizer...
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (1283 > 512). Running this sequence through the model will result in indexing errors
# Starting generation pipeline...
# Question: What is a lambda function in Python?
# Answer: /p>
# Generation completed.
# Source Document 1:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>It's an inline anonymous function.</p>
#  Tags: python lambda'
#
# Source Document 2:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>Lambda is more of a concept or programming technique then anything else. </p>
#
# <p>Basically it's the idea that you get a function (a first-class object in python) returned as a result of another function instead of an object or primitive type. I know, it's confusing.</p>
#
# <p>See this example from the <a href="http://docs.python.org/tutorial/controlflow.html#lambda-forms">python documentation</a>: </p>
#
# <pre><code>def make_incrementor(n):
#   return lambda x: x + n
# f = make_incrementor(42)
# f(0)
# &gt;&gt;&gt; 42
# f(1)
# &gt;&gt;&gt; 43
# </code></pre>
#
# <p>So make_incrementor creates a function that uses n in it's results. You could have a function that would increment a parameter by 2 like so: </p>
#
# <pre><code>f2 = make_incrementor(2)
# f2(3)
# &gt;&gt;&gt; 5
# </code></pre>
#
# <p>This is a very powerful idea in functional programming and functional programming languages like lisp &amp; scheme. </p>
#
# <p>Hope this helps.</p>
#  Tags: python lambda'
#
# Source Document 3:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p><code>lambda</code> is a way of defining an anonymous in-line function to accomplish some task versus defining it with the <code>def</code> keyword and calling it. Think of it as a shorthand you can use when you won't need to reuse a function. Anywhere you use lambda, you could substitute an explicitly called function: it's use is completely optional and left to the programmer as a matter of coding style.</p>
#
# <p>Example code (without lambda):</p>
#
# <pre><code>def numSquared(num):
#     return num**2
#
# for i in range(1,11):
#     print numSquared(i)
# </code></pre>
#
# <p>Example code (with lambda):</p>
#
# <pre><code>for i in range(1,11):
#     print (lambda x: x**2)(i)
# </code></pre>
#
# <p>A good beginner's discussion of <code>lambda</code>:
# <a href="http://diveintopython.net/power_of_introspection/lambda_functions.html" rel="nofollow" title="DiveIntoPython - Lambda">DiveIntPython.org - Lambda</a></p>
#  Tags: python lambda'
#
# Source Document 4:
# page_content='What exactly is "lambda" in Python? <p>I want to know what exactly is <code>lambda</code> in python? and where and why it is used.
# thanks</p>
#  <p>Lambdas are not anonymous functions.  Lambdas are anonymous <em>expressions</em>.</p>
#
# <p>They're accessed like functions, but they're not the same thing.  Functions allow complex tasks: flow control, variable declarations and lists of statements containing expressions.  Expressions are merely one part of a function, and that's what lambdas give you.  They're severely limited compared to functions.</p>
#
# <p>Python does not support anonymous functions.  For examples of languages that do, see Javascript and Lua.</p>
#
# <p>(Note: It's correct to call lambdas anonymous functions in functional languages, where the mathematical definition of "function" is used, but in procedural languages the word has a very different meaning than in mathematics.)</p>
#  Tags: python lambda'

# %%
# Import necessary libraries
from transformers import T5ForConditionalGeneration, T5Tokenizer, pipeline
import re

# Load the Flan-T5 model and tokenizer on GPU
print("Loading Flan-T5 model and tokenizer...")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base").to("cuda")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

# Create a text generation pipeline with controlled output
generation_pipeline = pipeline(
    "text2text-generation", model=model, tokenizer=tokenizer, device=0, max_new_tokens=100
)

# Function to clean HTML and truncate text to fit within model input limits
def clean_and_truncate(text, max_length=200):
    # Remove HTML tags
    text = re.sub(r'<[^>]+>', '', text)
    # Truncate the input text
    tokens = tokenizer(text, truncation=True, max_length=max_length, return_tensors="pt")
    return tokenizer.decode(tokens["input_ids"][0], skip_special_tokens=True)

# Sample question and documents (simulate document retrieval)
query = "What is a lambda function in Python?"
documents = [
    # Clean and truncated documents simulating retrieved content
    clean_and_truncate("What exactly is 'lambda' in Python? It's an inline anonymous function.", max_length=200),
    clean_and_truncate("Lambda functions in Python are used to define anonymous functions in a single line.", max_length=200)
]

# Prepare combined context for model input
combined_context = " ".join(documents)

# Run the model pipeline with query + context
input_text = f"Question: {query} Context: {combined_context}"
answer = generation_pipeline(input_text)[0]["generated_text"]

print(f"Question: {query}")
print(f"Answer: {answer}")
# Out:
# Loading Flan-T5 model and tokenizer...
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Question: What is a lambda function in Python?
# Answer: inline anonymous function
